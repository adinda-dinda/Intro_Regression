# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Import Data 'Housing data'

# %%
df = pd.read_csv('/content/HousingData.csv')

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90    NaN  36.2

# %%
len(df)
# Out:
# 506

# %%
df.tail()
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 501  0.06263  0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273     21.0
# 502  0.04527  0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273     21.0
# 503  0.06076  0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273     21.0
# 504  0.10959  0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273     21.0
# 505  0.04741  0.0  11.93   0.0  0.573  6.030   NaN  2.5050    1  273     21.0
#
#           B  LSTAT  MEDV
# 501  391.99    NaN  22.4
# 502  396.90   9.08  20.6
# 503  396.90   5.64  23.9
# 504  393.45   6.48  22.0
# 505  396.90   7.88  11.9

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.duplicated(['PTRATIO','MEDV']).sum()
# Out:
# 66

# %%
df.isna().sum()/len(df)*100
# Out:
# CRIM       3.952569
# ZN         3.952569
# INDUS      3.952569
# CHAS       3.952569
# NOX        0.000000
# RM         0.000000
# AGE        3.952569
# DIS        0.000000
# RAD        0.000000
# TAX        0.000000
# PTRATIO    0.000000
# B          0.000000
# LSTAT      3.952569
# MEDV       0.000000
# dtype: float64

# %%
df.isna().any()
# Out:
# CRIM        True
# ZN          True
# INDUS       True
# CHAS        True
# NOX        False
# RM         False
# AGE         True
# DIS        False
# RAD        False
# TAX        False
# PTRATIO    False
# B          False
# LSTAT       True
# MEDV       False
# dtype: bool

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     486 non-null    float64
#  1   ZN       486 non-null    float64
#  2   INDUS    486 non-null    float64
#  3   CHAS     486 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      486 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    486 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  486.000000  486.000000  486.000000  486.000000  506.000000  506.000000
# mean     3.611874   11.211934   11.083992    0.069959    0.554695    6.284634
# std      8.720192   23.388876    6.835896    0.255340    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.081900    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.253715    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.560263   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  486.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.518519    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
df['CRIM'].mean()
# Out:
# 3.6118739711934156

# %%
df['CRIM'] = df['CRIM'].fillna(df['CRIM'].mean())
df['ZN'] = df['ZN'].fillna(df['ZN'].mean())
df['INDUS'] = df['INDUS'].fillna(df['INDUS'].mean())
df['CHAS'] = df['CHAS'].fillna(df['CHAS'].mean())
df['AGE'] = df['AGE'].fillna(df['AGE'].mean())
df['LSTAT'] = df['LSTAT'].fillna(df['LSTAT'].mean())

# %%
df.isna().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
df = df.rename(columns={'CRIMM':'price'})

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B      LSTAT  MEDV
# 0  396.90   4.980000  24.0
# 1  396.90   9.140000  21.6
# 2  392.83   4.030000  34.7
# 3  394.63   2.940000  33.4
# 4  396.90  12.715432  36.2

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.611874   11.211934   11.083992    0.069959    0.554695    6.284634
# std      8.545770   22.921051    6.699165    0.250233    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.083235    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.290250    0.000000    9.900000    0.000000    0.538000    6.208500
# 75%      3.611874   11.211934   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.518519    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
import seaborn as sns
sns.boxplot(df ['ZN'])
# Out:
# <Axes: ylabel='ZN'>

# %%
df['ZN'].min() , df['ZN'].max()
# Out:
# (0.0, 100.0)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

df['ZN_minmax'] = MinMaxScaler().fit_transform(df[['ZN']].values.reshape(len(df),1))

# %%
df['ZN_minmax'].min() , df['ZN_minmax'].max()
# Out:
# (0.0, 1.0)

# %%
df[['ZN','ZN_minmax']]
# Out:
#        ZN  ZN_minmax
# 0    18.0       0.18
# 1     0.0       0.00
# 2     0.0       0.00
# 3     0.0       0.00
# 4     0.0       0.00
# ..    ...        ...
# 501   0.0       0.00
# 502   0.0       0.00
# 503   0.0       0.00
# 504   0.0       0.00
# 505   0.0       0.00
#
# [506 rows x 2 columns]

# %%
df[df['ZN']==1]
# Out:
# Empty DataFrame
# Columns: [CRIM, ZN, INDUS, CHAS, NOX, RM, AGE, DIS, RAD, TAX, PTRATIO, B, LSTAT, MEDV, ZN_minmax]
# Index: []

# %%
sns.displot(df['RM'],kde='hist')

# %%
sns.displot(df['AGE'],kde='hist')

# %%
sns.displot(df['NOX'],kde='hist')

# %%
sns.displot(df['DIS'],kde='hist')

# %%
sns.displot(df['DIS'],kde='hist')

# %%
sns.displot(df['CRIM'],kde='hist')

# %%
sns.displot(df['INDUS'],kde='hist')

# %%
sns.displot(df['CHAS'],kde='hist')

# %%
sns.displot(df['RAD'],kde='hist')

# %%
import numpy as np

df['DIS'] = np.log(df['DIS'])

sns.displot(df['DIS'],kde='hist')

# %%
counts_chas = df['CHAS'].value_counts()
counts_chas.colums = ['CHAS','count']
counts_chas
# Out:
# CHAS
# 0.000000    452
# 1.000000     34
# 0.069959     20
# Name: count, dtype: int64

# %%
counts_ZN = df['ZN'].value_counts()
counts_ZN.colums = ['ZN','count']
counts_ZN
# Out:
# ZN
# 0.000000      360
# 11.211934      20
# 20.000000      20
# 80.000000      14
# 22.000000      10
# 25.000000      10
# 12.500000      10
# 40.000000       6
# 45.000000       6
# 90.000000       5
# 30.000000       5
# 33.000000       4
# 21.000000       4
# 60.000000       4
# 95.000000       4
# 70.000000       3
# 55.000000       3
# 75.000000       3
# 52.500000       3
# 35.000000       2
# 82.500000       2
# 28.000000       2
# 85.000000       2
# 17.500000       1
# 100.000000      1
# 34.000000       1
# 18.000000       1
# Name: count, dtype: int64

# %%
counts_ZN = df['ZN'].value_counts()
counts_ZN.colums = ['ZN','jumlah']
np.shape(counts_ZN)
# Out:
# (27,)

# %%
counts_ZN = df['ZN'].value_counts().sort_index()
counts_ZN.colums = ['ZN','jumlah']
counts_ZN
# Out:
# ZN
# 0.000000      360
# 11.211934      20
# 12.500000      10
# 17.500000       1
# 18.000000       1
# 20.000000      20
# 21.000000       4
# 22.000000      10
# 25.000000      10
# 28.000000       2
# 30.000000       5
# 33.000000       4
# 34.000000       1
# 35.000000       2
# 40.000000       6
# 45.000000       6
# 52.500000       3
# 55.000000       3
# 60.000000       4
# 70.000000       3
# 75.000000       3
# 80.000000      14
# 82.500000       2
# 85.000000       2
# 90.000000       5
# 95.000000       4
# 100.000000      1
# Name: count, dtype: int64

# %%
counts_ZN = df['ZN'].value_counts().reset_index().sort_index() # Remove inplace=True
counts_ZN.columns = ['ZN','jumlah'] # Correct typo: colums to columns
counts_ZN
# Out:
#             ZN  jumlah
# 0     0.000000     360
# 1    11.211934      20
# 2    20.000000      20
# 3    80.000000      14
# 4    22.000000      10
# 5    25.000000      10
# 6    12.500000      10
# 7    40.000000       6
# 8    45.000000       6
# 9    90.000000       5
# 10   30.000000       5
# 11   33.000000       4
# 12   21.000000       4
# 13   60.000000       4
# 14   95.000000       4
# 15   70.000000       3
# 16   55.000000       3
# 17   75.000000       3
# 18   52.500000       3
# 19   35.000000       2
# 20   82.500000       2
# 21   28.000000       2
# 22   85.000000       2
# 23   17.500000       1
# 24  100.000000       1
# 25   34.000000       1
# 26   18.000000       1

# %%
plt.bar(counts_ZN['ZN'],counts_ZN['jumlah'])
plt.show()

# %%
sns.barplot(x=counts_ZN['ZN'],y=counts_ZN['jumlah'])
plt.show()
